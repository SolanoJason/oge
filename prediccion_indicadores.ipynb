# %% [markdown]
# # PREDICCION DE LOS INDICADORES DE CUMPLIMIENTO DE LOS PROCESOS DE LAS ESCUELAS O DEPARTAMENTOS DE LA UNASAM

# %%
from prediccion_indicadores import prepare_data, get_timeline, plot_timeline

# %%
# Cargamos los datos desde un archivo Excel para el análisis e indicamos el tipo ('escuela' o 'departamento')

prepare_data('escuela_indicadores.xlsx', tipo='escuela')

# %%
# Especificamos la escuela, proceso y el numero de semestres a predecir
nombre = 'ADMINISTRACIÓN'
proceso = 'Carga'
n_predicciones = 3

plot_timeline(nombre, proceso, n_predicciones)

# %%
# Si queremos los numeros exactos usamos 'get_timeline' para obtener la tabla de datos que se graficó
get_timeline(nombre, proceso, n_predicciones)
# Out:
#    semestre         escuela proceso  a_tiempo  fuera_tiempo       date  \
# 0    2018-1  ADMINISTRACIÓN   Carga        62             6 2018-01-01
# 1    2018-2  ADMINISTRACIÓN   Carga        65             2 2018-07-01
# 2    2019-1  ADMINISTRACIÓN   Carga        68             2 2019-01-01
# 3    2019-2  ADMINISTRACIÓN   Carga        63             4 2019-07-01
# 4    2020-1  ADMINISTRACIÓN   Carga         0            72 2020-01-01
# 5    2020-2  ADMINISTRACIÓN   Carga        67             0 2020-07-01
# 6    2021-1  ADMINISTRACIÓN   Carga        77             2 2021-01-01
# 7    2021-2  ADMINISTRACIÓN   Carga         0            64 2021-07-01
# 8    2022-1  ADMINISTRACIÓN   Carga         8            68 2022-01-01
# 9    2022-2  ADMINISTRACIÓN   Carga        60            15 2022-07-01
# 10   2023-1  ADMINISTRACIÓN   Carga        52            24 2023-01-01
# 11   2023-2  ADMINISTRACIÓN   Carga         0            80 2023-07-01
# ...

# %%
# Cargamos los datos desde un archivo Excel para el análisis e indicamos el tipo ('escuela' o 'departamento')

prepare_data('departamento_indicadores.xlsx', tipo='departamento')

# %%
# Especificamos la escuela, proceso y el numero de semestres a predecir
nombre = 'ECONOMÍA'
proceso = 'Fórmulas'
n_predicciones = 3

plot_timeline(nombre, proceso, n_predicciones)

# %%
# Si queremos los numeros exactos usamos 'get_timeline' para obtener la tabla de datos que se graficó

get_timeline(nombre, proceso, n_predicciones)
# Out:
#    semestre departamento   proceso  a_tiempo  fuera_tiempo       date  \
# 0    2018-1     ECONOMÍA  Fórmulas        13            65 2018-01-01
# 1    2018-2     ECONOMÍA  Fórmulas        14            74 2018-07-01
# 2    2019-1     ECONOMÍA  Fórmulas         6            78 2019-01-01
# 3    2019-2     ECONOMÍA  Fórmulas        11            71 2019-07-01
# 4    2020-1     ECONOMÍA  Fórmulas         0            86 2020-01-01
# 5    2020-2     ECONOMÍA  Fórmulas        38            53 2020-07-01
# 6    2021-1     ECONOMÍA  Fórmulas        56            41 2021-01-01
# 7    2021-2     ECONOMÍA  Fórmulas         0            92 2021-07-01
# 8    2022-1     ECONOMÍA  Fórmulas         0            94 2022-01-01
# 9    2022-2     ECONOMÍA  Fórmulas         0            81 2022-07-01
# 10   2023-1     ECONOMÍA  Fórmulas         0            70 2023-01-01
# 11   2023-2     ECONOMÍA  Fórmulas        47            38 2023-07-01
# ...

# %%
from prediccion_carga_academica import predecir_carga_academica, predecir_profesor, semestre_2022_2, df_test

# %%
escuela = '36'
curso = 'C78'
#profesor = 'WJML01'
#profesor = 'ACL529'
profesor = 'SZM001'

# %%
predecir_carga_academica(profesor)
# Out:
#   Escuela Curricula   Curso Semestre Trabajador_x  \
# 0      25        04  250255   2022-2       SZM001
# 1      25        04  2502A1   2022-2       SZM001
#
#                                         Nombre
# 0                             PROGRAMACION III
# 1  SISTEMAS EXPERTOS E INTELIGENCIA ARTIFICIAL

# %%
predecir_profesor('25', '250255')
# Out:
# 'SZM001'
